# %%
import pandas as pd
from IPython.display import display
import string
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'figure.max_open_warning': 0})
from decimal import Decimal

from orangecontrib.bioinformatics.geneset.__init__ import list_all
from orangecontrib.bioinformatics.utils.statistics import Hypergeometric

import helper_enrichment as enr
from helper import PATH_RESULTS
# Out:
# /home/karin/Documents/git/orange3venv/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Path for expression data (mergedGenes_RPKUM.tsv)
path_genes='Data/'
#Path for regulons
path_regulons=PATH_RESULTS+'regulons/'
#Paths for milestones
path_milestones=PATH_RESULTS+'milestones/'
#Paths for disaggregation genes
path_disaggregation=PATH_RESULTS+'disaggregation/'

# %% [markdown]
# ## Load gene sets

# %%
# Reference genes and conversion of gene names to EID
genes = pd.read_csv(path_genes + 'mergedGenes_RPKUM.tsv', sep='\t', index_col=0)
ALL_GENE_NAMES= set(genes[(genes != 0).any(axis=1)].index)
NAME_EID=enr.name_genes_entrez(gene_names=ALL_GENE_NAMES, key_entrez=False)
ALL_GENE_NAMES_EID=enr.convert_EID(genes=ALL_GENE_NAMES, name_EID=NAME_EID)

# %%
# Get gene sets
gene_sets=list(list_all(organism='44689'))
GENE_SETS_ONTOLOGY=enr.get_gene_sets(gene_set_names=gene_sets, go_slims=True,set_sizes=(5,500),
                                     reference=ALL_GENE_NAMES_EID)

print('N gene sets per ontology:',{k:len(v) for k,v in GENE_SETS_ONTOLOGY.items()})
# Out:
# N gene sets per ontology: {('GO', 'molecular_function'): 35, ('Custom', 'Baylor'): 15, ('Dictybase', 'Phenotypes'): 207, ('KEGG', 'Pathways'): 95, ('GO', 'cellular_component'): 24, ('GO', 'biological_process'): 52}

# %% [markdown]
# ## Enrichment reports
# The enrichment reports show enriched gene sets filtered based on FDR<=0.25 and gene set-gene group overlap>=2.
# Barplots show fold enrichment coloured by FDR. Barplot colourscale is consistent across enrichment reports, but barplot x-axis range differs.

# %%
# Gene set enrichment filtering parameters
PADJ=0.25
MIN_OVERLAP=2
# Plotting parameters
MAX_FE_BAR=None
MIN_FDR_BAR=10**(-10)
LFDR_BASE_BAR=10
CMAP_FDR_BAR=['#bede57','#5fb526','#36801d','#015713','#000803']

# %% [markdown]
# Legend for fold change barplot colour based on FDR.

# %%
# Legend for fold change barplot
# %matplotlib agg
fig,ax=enr.plot_legend_enrichment_bar(cmap=CMAP_FDR_BAR, min_FDR=MIN_FDR_BAR,used_padj=PADJ,base=LFDR_BASE_BAR)
display(fig)

# %% [markdown]
# ### Regulons

# %% [markdown]
# #### Regulons clustering based on all strains

# %%
# %matplotlib agg
regulons=pd.read_table(path_regulons+'regulonsAll.tab',index_col=0)
for group in range(1,len(regulons['Cluster'].unique())+1):
    enriched=enr.group_diff_enrichment(query_names=list(regulons.query('Cluster =="'+'C'+str(group)+'"').index),
                                       group='C'+str(group),
                                       name_eid=NAME_EID,all_gene_names_eid=ALL_GENE_NAMES_EID, 
                                       gene_sets_ontology=GENE_SETS_ONTOLOGY,
                                       use_annotated_genes=True,
                                       min_overlap=MIN_OVERLAP,padj=PADJ,
                                       make_enrichment_bar=True,
                                       max_FE_bar=MAX_FE_BAR, min_FDR_bar=MIN_FDR_BAR,cmap_FDR_bar=CMAP_FDR_BAR,
                                       lFDR_base_bar=LFDR_BASE_BAR
                                      )
    display(enriched[1][0])
plt.close('all')
# Out:
# ***  C1 selected: 30 with EID: 30
# Genes annotated with a gene set in reference 37.8% and group 73.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 20 out of 22 group genes used for enrichment calculation.
# ***  C2 selected: 61 with EID: 61
# Genes annotated with a gene set in reference 37.8% and group 64.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 30 out of 39 group genes used for enrichment calculation.
# ***  C3 selected: 67 with EID: 67
# Genes annotated with a gene set in reference 37.8% and group 97.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 62 out of 65 group genes used for enrichment calculation.
# ***  C4 selected: 57 with EID: 57
# Genes annotated with a gene set in reference 37.8% and group 51.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 20 out of 29 group genes used for enrichment calculation.
# ***  C5 selected: 47 with EID: 46
# Genes annotated with a gene set in reference 37.8% and group 93.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 35 out of 43 group genes used for enrichment calculation.
# ***  C6 selected: 72 with EID: 72
# Genes annotated with a gene set in reference 37.8% and group 56.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 32 out of 40 group genes used for enrichment calculation.
# ***  C7 selected: 39 with EID: 39
# Genes annotated with a gene set in reference 37.8% and group 41.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 14 out of 16 group genes used for enrichment calculation.
# ***  C8 selected: 23 with EID: 23
# Genes annotated with a gene set in reference 37.8% and group 43.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 6 out of 10 group genes used for enrichment calculation.
# ***  C9 selected: 36 with EID: 36
# Genes annotated with a gene set in reference 37.8% and group 53.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 18 out of 19 group genes used for enrichment calculation.
# ***  C10 selected: 21 with EID: 21
# Genes annotated with a gene set in reference 37.8% and group 86.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 18 out of 18 group genes used for enrichment calculation.
# ***  C11 selected: 90 with EID: 90
# Genes annotated with a gene set in reference 37.8% and group 37.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 18 out of 33 group genes used for enrichment calculation.
# ***  C12 selected: 62 with EID: 62
# Genes annotated with a gene set in reference 37.8% and group 81.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 41 out of 50 group genes used for enrichment calculation.
# ***  C13 selected: 45 with EID: 45
# Genes annotated with a gene set in reference 37.8% and group 69.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 23 out of 31 group genes used for enrichment calculation.
# ***  C14 selected: 19 with EID: 19
# Genes annotated with a gene set in reference 37.8% and group 84.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 14 out of 16 group genes used for enrichment calculation.
# ***  C15 selected: 88 with EID: 88
# Genes annotated with a gene set in reference 37.8% and group 73.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 52 out of 64 group genes used for enrichment calculation.
# ***  C16 selected: 76 with EID: 76
# Genes annotated with a gene set in reference 37.8% and group 51.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 36 out of 39 group genes used for enrichment calculation.
# ***  C17 selected: 59 with EID: 57
# Genes annotated with a gene set in reference 37.8% and group 40.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 15 out of 23 group genes used for enrichment calculation.
# ***  C18 selected: 58 with EID: 57
# Genes annotated with a gene set in reference 37.8% and group 44.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 18 out of 25 group genes used for enrichment calculation.
# ***  C19 selected: 54 with EID: 54
# Genes annotated with a gene set in reference 37.8% and group 37.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 7 out of 20 group genes used for enrichment calculation.
# ***  C20 selected: 45 with EID: 45
# Genes annotated with a gene set in reference 37.8% and group 27.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 8 out of 12 group genes used for enrichment calculation.
# ***  C21 selected: 48 with EID: 48
# Genes annotated with a gene set in reference 37.8% and group 25.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 8 out of 12 group genes used for enrichment calculation.

# %% [markdown]
# #### Regulons clustering based on AX4

# %%
# %matplotlib agg
regulons=pd.read_table(path_regulons+'regulonsAX4.tab',index_col=0)
for group in range(1,len(regulons['Cluster'].unique())+1):
    cluster='C'+str(group)
    print('*** Cluster %s (%s)' %(cluster,string.ascii_uppercase[group-1]))
    enriched=enr.group_diff_enrichment(query_names=list(regulons.query('Cluster =="'+'C'+str(group)+'"').index),
                                       group=cluster,
                                       name_eid=NAME_EID,all_gene_names_eid=ALL_GENE_NAMES_EID, 
                                       gene_sets_ontology=GENE_SETS_ONTOLOGY,
                                       use_annotated_genes=True,
                                       min_overlap=MIN_OVERLAP,padj=PADJ,
                                       make_enrichment_bar=True,
                                       max_FE_bar=MAX_FE_BAR, min_FDR_bar=MIN_FDR_BAR,
                                       cmap_FDR_bar=CMAP_FDR_BAR,
                                       lFDR_base_bar=LFDR_BASE_BAR
                                      )
    display(enriched[1][0])
plt.close('all')
# Out:
# *** Cluster C1 (A)
# ***  C1 selected: 31 with EID: 31
# Genes annotated with a gene set in reference 37.8% and group 74.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 20 out of 23 group genes used for enrichment calculation.
# *** Cluster C2 (B)
# ***  C2 selected: 74 with EID: 74
# Genes annotated with a gene set in reference 37.8% and group 89.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 62 out of 66 group genes used for enrichment calculation.
# *** Cluster C3 (C)
# ***  C3 selected: 97 with EID: 97
# Genes annotated with a gene set in reference 37.8% and group 61.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 38 out of 59 group genes used for enrichment calculation.
# *** Cluster C4 (D)
# ***  C4 selected: 49 with EID: 49
# Genes annotated with a gene set in reference 37.8% and group 94.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 35 out of 46 group genes used for enrichment calculation.
# *** Cluster C5 (E)
# ***  C5 selected: 35 with EID: 35
# Genes annotated with a gene set in reference 37.8% and group 43.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 13 out of 15 group genes used for enrichment calculation.
# *** Cluster C6 (F)
# ***  C6 selected: 99 with EID: 99
# Genes annotated with a gene set in reference 37.8% and group 49.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 35 out of 49 group genes used for enrichment calculation.
# *** Cluster C7 (G)
# ***  C7 selected: 38 with EID: 38
# Genes annotated with a gene set in reference 37.8% and group 50.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 18 out of 19 group genes used for enrichment calculation.
# *** Cluster C8 (H)
# ***  C8 selected: 118 with EID: 118
# Genes annotated with a gene set in reference 37.8% and group 39.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 34 out of 46 group genes used for enrichment calculation.
# *** Cluster C9 (I)
# ***  C9 selected: 67 with EID: 67
# Genes annotated with a gene set in reference 37.8% and group 87.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 56 out of 58 group genes used for enrichment calculation.
# *** Cluster C10 (J)
# ***  C10 selected: 141 with EID: 141
# Genes annotated with a gene set in reference 37.8% and group 74.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 87 out of 104 group genes used for enrichment calculation.
# *** Cluster C11 (K)
# ***  C11 selected: 93 with EID: 93
# Genes annotated with a gene set in reference 37.8% and group 68.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 52 out of 63 group genes used for enrichment calculation.
# *** Cluster C12 (L)
# ***  C12 selected: 44 with EID: 44
# Genes annotated with a gene set in reference 37.8% and group 52.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 22 out of 23 group genes used for enrichment calculation.
# *** Cluster C13 (M)
# ***  C13 selected: 144 with EID: 141
# Genes annotated with a gene set in reference 37.8% and group 28.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 25 out of 40 group genes used for enrichment calculation.
# *** Cluster C14 (N)
# ***  C14 selected: 67 with EID: 66
# Genes annotated with a gene set in reference 37.8% and group 23.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 7 out of 15 group genes used for enrichment calculation.

# %% [markdown]
# ### Milestones

# %%
data_deseq=pd.read_table(path_milestones+'DE_combined.tsv',index_col=0)
data_impulse=pd.read_table(path_milestones+'DEacrossMainStages_AX4_summary_fdr0.001.tsv',index_col=0)
data=pd.concat([data_deseq,data_impulse],sort=True,axis=1)

# %%
comparisons=[comparison.replace('_FDR_overall','') for comparison in data.columns[
    data.columns.str.contains('_FDR_overall')]]
max_fdr_de=0.01
min_abs_lfc_de=2

# %%
# %matplotlib agg
for comparison in comparisons:
    for lFC_filter in ['>= ','<= -']:
        query_names=list(data.query( comparison + '_log2FoldChange ' +lFC_filter+ str(min_abs_lfc_de) +
                          ' & ' + comparison + '_FDR_overall <= ' + str(max_fdr_de) +
                          ' & ' + comparison + ' == 1').index)
        comparison_title=comparison+' lFC '+lFC_filter+ str(
            min_abs_lfc_de)+' and FDR_overall <= ' + str(max_fdr_de)
        if(len(query_names)>0):
            enriched=enr.group_diff_enrichment(query_names=query_names,
                                               group=comparison_title,
                                               name_eid=NAME_EID,all_gene_names_eid=ALL_GENE_NAMES_EID, 
                                               gene_sets_ontology=GENE_SETS_ONTOLOGY,
                                               use_annotated_genes=True,
                                               min_overlap=MIN_OVERLAP,padj=PADJ,
                                               make_enrichment_bar=True,
                                               max_FE_bar=MAX_FE_BAR, min_FDR_bar=MIN_FDR_BAR,
                                               cmap_FDR_bar=CMAP_FDR_BAR,lFDR_base_bar=LFDR_BASE_BAR
                                              )
            display(enriched[1][0])
        else:
            print('***  '+comparison_title+' selected: 0\n')
plt.close('all')
# Out:
# ***  no_agg_stream lFC >= 2 and FDR_overall <= 0.01 selected: 247 with EID: 246
# Genes annotated with a gene set in reference 37.8% and group 31.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 0 out of 77 group genes used for enrichment calculation.
# None
# ***  no_agg_stream lFC <= -2 and FDR_overall <= 0.01 selected: 294 with EID: 292
# Genes annotated with a gene set in reference 37.8% and group 46.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 84 out of 133 group genes used for enrichment calculation.
# ***  stream_lag lFC >= 2 and FDR_overall <= 0.01 selected: 71 with EID: 70
# Genes annotated with a gene set in reference 37.8% and group 39.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 12 out of 27 group genes used for enrichment calculation.
# ***  stream_lag lFC <= -2 and FDR_overall <= 0.01 selected: 1 with EID: 1
# Genes annotated with a gene set in reference 37.8% and group 0.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 0 out of 0 group genes used for enrichment calculation.
# None
# ***  lag_tag lFC >= 2 and FDR_overall <= 0.01 selected: 260 with EID: 259
# Genes annotated with a gene set in reference 37.8% and group 52.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 85 out of 135 group genes used for enrichment calculation.
# ***  lag_tag lFC <= -2 and FDR_overall <= 0.01 selected: 11 with EID: 11
# Genes annotated with a gene set in reference 37.8% and group 36.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 0 out of 4 group genes used for enrichment calculation.
# None
# ***  tag_tip lFC >= 2 and FDR_overall <= 0.01 selected: 35 with EID: 35
# Genes annotated with a gene set in reference 37.8% and group 60.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 20 out of 21 group genes used for enrichment calculation.
# ***  tag_tip lFC <= -2 and FDR_overall <= 0.01 selected: 20 with EID: 20
# Genes annotated with a gene set in reference 37.8% and group 45.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 6 out of 9 group genes used for enrichment calculation.
# ***  tip_slug lFC >= 2 and FDR_overall <= 0.01 selected: 12 with EID: 12
# Genes annotated with a gene set in reference 37.8% and group 100.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 9 out of 12 group genes used for enrichment calculation.
# ***  tip_slug lFC <= -2 and FDR_overall <= 0.01 selected: 0
#
# ***  slug_mhat lFC >= 2 and FDR_overall <= 0.01 selected: 209 with EID: 209
# Genes annotated with a gene set in reference 37.8% and group 46.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 53 out of 97 group genes used for enrichment calculation.
# ***  slug_mhat lFC <= -2 and FDR_overall <= 0.01 selected: 0
#
# ***  mhat_cul lFC >= 2 and FDR_overall <= 0.01 selected: 45 with EID: 45
# Genes annotated with a gene set in reference 37.8% and group 31.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 8 out of 14 group genes used for enrichment calculation.
# ***  mhat_cul lFC <= -2 and FDR_overall <= 0.01 selected: 9 with EID: 9
# Genes annotated with a gene set in reference 37.8% and group 78.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 7 out of 7 group genes used for enrichment calculation.
# ***  cul_FB lFC >= 2 and FDR_overall <= 0.01 selected: 176 with EID: 175
# Genes annotated with a gene set in reference 37.8% and group 29.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 25 out of 51 group genes used for enrichment calculation.
# ***  cul_FB lFC <= -2 and FDR_overall <= 0.01 selected: 3 with EID: 3
# Genes annotated with a gene set in reference 37.8% and group 67.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 0 out of 2 group genes used for enrichment calculation.
# None

# %% [markdown]
# ### Disaggregation

# %% [markdown]
# #### DE in Nichols, et al. (2020) data: media at 0.5-2hr vs all buffer samples

# %%
query_data=pd.read_table(
    path_disaggregation+'mediaVSbufferAll_alternativegreater_FDRoptim0.01_DE_media0.5hr1hr2hr_ref_bufferAll.tsv',
    index_col=0)
filter_value='padj<=0.01 & log2FoldChange >= 2'
de_mb=set(query_data.query(filter_value).index)

# %%
# %matplotlib agg
figs=[]
enriched=enr.group_diff_enrichment(query_names=de_mb,
                                   group='media 0.5-2hr vs buffer all',
                                   name_eid=NAME_EID,all_gene_names_eid=ALL_GENE_NAMES_EID, 
                                   gene_sets_ontology=GENE_SETS_ONTOLOGY,
                                   use_annotated_genes=True,
                                   min_overlap=MIN_OVERLAP,padj=PADJ,
                                   make_enrichment_bar=True,
                                   max_FE_bar=MAX_FE_BAR, min_FDR_bar=MIN_FDR_BAR,
                                   cmap_FDR_bar=CMAP_FDR_BAR,lFDR_base_bar=LFDR_BASE_BAR
                                  )
figs.append(enriched[1])
display(enriched[1][0])
plt.close('all')
# Out:
# ***  media 0.5-2hr vs buffer all selected: 360 with EID: 359
# Genes annotated with a gene set in reference 37.8% and group 46.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 106 out of 164 group genes used for enrichment calculation.

# %%
# Check overlap of disaggreagtion genes with genes obtained on Nichols, et al. (2020) data 
hypergeometric=Hypergeometric()
def nichols_overlap(gene_names):
    ref_overlap=ALL_GENE_NAMES & de_mb
    query_overlap = set(gene_names) & de_mb
    p=hypergeometric.p_value(len(query_overlap), len(ALL_GENE_NAMES), len(ref_overlap), len(gene_names))
    print("DE on data from Nichols, et al. (2020) (deMB): \ndeMB overlap with nonzero genes: %.1f%% and group: %.1f%%; p-val: %.2E\n" % (
            (len(ref_overlap) / len(ALL_GENE_NAMES)) * 100, (len(query_overlap)/len(gene_names)) * 100,Decimal(str(p))))

# %% [markdown]
# #### Overexpressed in tag_dis at 8-12hr compared to all AX4 timepoints

# %%
# %matplotlib agg
query_data=pd.read_table(
    path_disaggregation+'tagdisVSAX4all_alternativegreater_FDRoptim0.01_DE_tgrB1hr8hr10hr12andtgrB1C1hr8hr10hr12_ref_AX4all.tsv',
    index_col=0)
filter_value='padj<=0.01 & log2FoldChange >= 2'
query_names=query_data.query(filter_value).index
enriched=enr.group_diff_enrichment(query_names=query_names,
                                   group='tag_dis 8-12hr vs AX4 all',
                                   name_eid=NAME_EID,all_gene_names_eid=ALL_GENE_NAMES_EID, 
                                   gene_sets_ontology=GENE_SETS_ONTOLOGY,
                                   use_annotated_genes=True,
                                   min_overlap=MIN_OVERLAP,padj=PADJ,
                                   make_enrichment_bar=True,
                                   max_FE_bar=MAX_FE_BAR, min_FDR_bar=MIN_FDR_BAR,
                                   cmap_FDR_bar=CMAP_FDR_BAR, lFDR_base_bar=LFDR_BASE_BAR
                                  )
display(enriched[1][0])

nichols_overlap(query_names)

plt.close('all')
# Out:
# ***  tag_dis 8-12hr vs AX4 all selected: 103 with EID: 102
# Genes annotated with a gene set in reference 37.8% and group 20.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 17 out of 20 group genes used for enrichment calculation.
# DE on data from Nichols, et al. (2020) (deMB):
# deMB overlap with nonzero genes: 2.9% and group: 2.9%; p-val: 5.77E-01

# %% [markdown]
# #### Upregulated between specific timepoints in tgrB1 and tgrB1C1, but not in AX4, tagB, or comH

# %%
def de_genes(file, filter_str):
    return set(pd.read_table(file,index_col=0).query(filter_str).index)

# %matplotlib agg
for times in [[4,6],[6,8],[8,12]]:
    filter_value='padj<=0.01 & log2FoldChange >= 1.32'
    de_AX4=de_genes(file=path_disaggregation+'AX4_confoundRep_FDRoptim0.01_DE_hr'+str(times[1])+
        '_ref_hr'+str(times[0])+'.tsv', filter_str=filter_value)
    de_tagB=de_genes(file=path_disaggregation+'comH_confoundRep_FDRoptim0.01_DE_hr'+str(times[1])+
        '_ref_hr'+str(times[0])+'.tsv', filter_str=filter_value)
    de_comH=de_genes(file=path_disaggregation+'tagB_confoundRep_FDRoptim0.01_DE_hr'+str(times[1])+
        '_ref_hr'+str(times[0])+'.tsv', filter_str=filter_value)
    de_tgrB1=de_genes(file=path_disaggregation+'tgrB1_confoundRep_FDRoptim0.01_DE_hr'+str(times[1])+
        '_ref_hr'+str(times[0])+'.tsv', filter_str=filter_value)
    de_tgrB1C1=de_genes(file=path_disaggregation+'tgrB1C1_confoundRep_FDRoptim0.01_DE_hr'+str(times[1])+
        '_ref_hr'+str(times[0])+'.tsv', filter_str=filter_value)
    query_names=(de_tgrB1 & de_tgrB1C1)-( de_AX4 |de_tagB | de_comH)
    enriched=enr.group_diff_enrichment(query_names=query_names,
                                       group=str(times[1])+'hr vs '+str(times[0])+'hr',
                                       name_eid=NAME_EID,all_gene_names_eid=ALL_GENE_NAMES_EID, 
                                       gene_sets_ontology=GENE_SETS_ONTOLOGY,
                                       use_annotated_genes=True,
                                       min_overlap=MIN_OVERLAP,padj=PADJ,
                                       make_enrichment_bar=True,
                                       max_FE_bar=MAX_FE_BAR, min_FDR_bar=MIN_FDR_BAR,
                                       cmap_FDR_bar=CMAP_FDR_BAR, lFDR_base_bar=LFDR_BASE_BAR
                                      )
    display(enriched[1][0])
    
    nichols_overlap(query_names)
    
plt.close('all')
# Out:
# ***  6hr vs 4hr selected: 74 with EID: 74
# Genes annotated with a gene set in reference 37.8% and group 43.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 21 out of 32 group genes used for enrichment calculation.
# DE on data from Nichols, et al. (2020) (deMB):
# deMB overlap with nonzero genes: 2.9% and group: 0.0%; p-val: 1.00E+00
#
# ***  8hr vs 6hr selected: 72 with EID: 70
# Genes annotated with a gene set in reference 37.8% and group 49.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 13 out of 34 group genes used for enrichment calculation.
# DE on data from Nichols, et al. (2020) (deMB):
# deMB overlap with nonzero genes: 2.9% and group: 2.8%; p-val: 6.21E-01
#
# ***  12hr vs 8hr selected: 218 with EID: 217
# Genes annotated with a gene set in reference 37.8% and group 47.0%
# Enrichment at FDR: 0.25 and min group - gene set overlap 2
# N group genes in displayed gene sets: 70 out of 103 group genes used for enrichment calculation.
# DE on data from Nichols, et al. (2020) (deMB):
# deMB overlap with nonzero genes: 2.9% and group: 32.1%; p-val: 9.25E-55
